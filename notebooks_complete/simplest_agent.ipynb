# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """,
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy is ice cream?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Ice cream can fit in a healthy diet in moderation. Pros: calcium, protein from dairy; some vitamins. Cons: high in added sugar and saturated fat; high in calories per serving.
#
#     Tips:
#     - Choose smaller portions (1/2 cup or less).
#     - Look for lower-fat or lower-sugar options, or enjoy frozen yogurt, sorbet, or fruit-based desserts.
#     - Pair with fruit or nuts to add fiber and satiety.
#     - If you have dietary goals (weight, blood sugar, cholesterol), factor in it within your daily intake.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are generally healthy as part of a balanced diet.
#
# Key points:
# - Nutrients: potassium, vitamin B6, vitamin C, fiber.
# - Benefits: supports heart health, digestion, steady energy (carbs are mostly natural sugars and starch), can help with satiety.
# - Calories: about 90–105 kcal for a medium banana.
# - Considerations: ripe bananas have more sugar; unripe have more resistant starch (may aid digestion). Most people can eat 1–2 daily.
# - Downsides: rare allergies; people with diabetes should monitor portion since sugars add up.
#
# Tips: pair with protein or healthy fats (e.g., peanut butter) for staying power.

# %% [markdown]
# _Good Job!_
